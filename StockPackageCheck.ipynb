# %%
import StockAnalysisPackage as sap

# %%
stock = sap.StockAnalysis(symbol='AMXN', start_date='2022-01-01', end_date='2023-01-01')
stock.fetch_stock_data()
# Out:
# Symbol Error: Ticker does not belong to stock/equity

# %%
stock = sap.StockAnalysis(symbol='LXEO', start_date='2022-01-01', end_date='2023-01-01')
stock.fetch_stock_data()
# Out:
# Date Error: Start Date before stock List Date

# %%
stock = sap.StockAnalysis(symbol='AAPL', start_date='2022-01-01', end_date='2024-10-01')
stock.fetch_stock_data()
# Out:
# Date Error: End Date after today's date

# %%
stock = sap.StockAnalysis(symbol='AAPL', start_date='2022-01-01', end_date='2023-01-01')
stock.fetch_stock_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Stock data fetched successfully.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    datetime64[ns]
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB
# None

# %%
stock.visualize_candlestick()

# %%
stock.visualize_candlestick('2022-06-01','2023-01-01')

# %%
stock.visualize_candlestick('2021-06-01','2023-01-01')
# Out:
# Date Error: Plot Start date provided is before the Data Fetch start date

# %%
stock.visualize_candlestick('2022-06-01','2024-10-01')
# Out:
# Date Error: Plot End date provided is after the Data Fetch end date

# %%
stock.calculate_moving_average(20)
# Out:
# Moving average (window=20) calculated successfully.

# %%
stock.visualize_moving_average()

# %%
stock.visualize_moving_average('2022-06-01','2023-01-01')

# %%
stock.visualize_moving_average('2021-06-01','2023-01-01')
# Out:
# Date Error: Plot Start date provided is before the Data Fetch start date

# %%
stock.visualize_moving_average('2022-06-01','2024-10-01')
# Out:
# Date Error: Plot End date provided is after the Data Fetch end date

# %%
stock.perform_macd()
# Out:
# MACD analysis performed successfully.

# %%
stock.visualize_macd()

# %%
stock.visualize_macd('2022-06-01','2023-01-01')

# %%
stock.visualize_macd('2021-06-01','2023-01-01')
# Out:
# Date Error: Plot Start date provided is before the Data Fetch start date

# %%
stock.visualize_macd('2022-06-01','2024-10-01')
# Out:
# Date Error: Plot End date provided is after the Data Fetch end date

# %%
stock.get_latest_news()
# Out:
# Title:  Surge in Tech Giants' S&P 500 Influence Despite Mixed Performances
# Link:  https://finance.yahoo.com/news/surge-tech-giants-p-500-151747571.html
# Publisher:  GuruFocus.com
#
#
# Title:  Apple Stock Has 20% Upside, According to 1 Wall Street Analyst
# Link:  https://finance.yahoo.com/m/7e701866-caca-3c0a-8542-3ebdd070f0af/apple-stock-has-20%25-upside%2C.html
# Publisher:  Motley Fool
#
#
# Title:  Apple Signal of AI Intent Unleashes $112 Billion Stock Surge
# Link:  https://finance.yahoo.com/news/apple-signal-ai-intent-unleashes-114945606.html
# Publisher:  Bloomberg
#
#
# Title:  Should You Invest in Apple (AAPL) Based on Bullish Wall Street Views?
# Link:  https://finance.yahoo.com/news/invest-apple-aapl-based-bullish-133009427.html
# Publisher:  Zacks
#
#
# Title:  JPMorgan, Wells Fargo, and Citigroup report: Yahoo Finance
# Link:  https://finance.yahoo.com/video/jpmorgan-wells-fargo-citigroup-report-113007678.html
# Publisher:  Yahoo Finance Video
#
#
# ...

# %%
stock.calculate_bollinger_bands(window=20, num_std=2)
# Out:
# Bollinger Bands (window=20, num_std=2) calculated successfully.

# %%
stock.visualize_bollinger_bands('2022-06-01', '2023-01-01')

# %%
stock.calculate_rsi(window=14)
# Out:
# RSI (window=14) calculated successfully.

# %%
stock.visualize_rsi('2022-06-01', '2023-01-01')

# %%
stock.perform_macd()
# Out:
# MACD analysis performed successfully.

# %%
stock.visualize_macd_histogram('2022-06-01', '2023-01-01')
